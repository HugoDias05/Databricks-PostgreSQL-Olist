# %%
# %run "../00_config/00_env_variables"

# %%
# Import Spark
from pyspark.sql import SparkSession

# Test reading a table
test_df = spark.read.jdbc(
    url=jdbc_url,
    table="olist_orders_dataset",
    properties=connection_properties
)

display(test_df.limit(10))
