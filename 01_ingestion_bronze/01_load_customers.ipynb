# %%
# %run "../00_config/00_env_variables"

# %%
# Load customers table from PostgreSQL into Bronze Layer

df_customers = spark.read.jdbc(
    url=jdbc_url,
    table="olist_customers_dataset",
    properties=connection_properties
)

# Save as a Delta table in the Bronze layer
df_customers.write.mode("overwrite").saveAsTable("project_4.bronze.customers")

print("Customers table ingested into Bronze layer ✅")

# %%
# Load orders table from PostgreSQL into Bronze Layer

df_customers = spark.read.jdbc(
    url=jdbc_url,
    table="olist_orders_dataset",
    properties=connection_properties
)

# Save as a Delta table in the Bronze layer
df_customers.write.mode("overwrite").saveAsTable("project_4.bronze.orders")

print("Customers table ingested into Bronze layer ✅")

# %%
# Load orders items table from PostgreSQL into Bronze Layer

df_customers = spark.read.jdbc(
    url=jdbc_url,
    table="olist_order_items_dataset",
    properties=connection_properties
)

# Save as a Delta table in the Bronze layer
df_customers.write.mode("overwrite").saveAsTable("project_4.bronze.orders_items")

print("Customers table ingested into Bronze layer ✅")

# %%
# Load products table from PostgreSQL into Bronze Layer

df_customers = spark.read.jdbc(
    url=jdbc_url,
    table="olist_products_dataset",
    properties=connection_properties
)

# Save as a Delta table in the Bronze layer
df_customers.write.mode("overwrite").saveAsTable("project_4.bronze.products")

print("Customers table ingested into Bronze layer ✅")
